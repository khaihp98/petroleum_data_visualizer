# %%
import lasio
from welly import well
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
las = lasio.read("./Data/welllog.las")

# %%
las.sections.keys()
# Out:
# dict_keys(['Version', 'Well', 'Curves', 'Parameter', 'Other'])

# %%
for count, curve in enumerate(las.curves):
    print(f"Curve: {curve.mnemonic}, \t Units: {curve.unit}, \t Description: {curve.descr}")
print(f"There are a total of: {count+1} curves present within this file")
# Out:
# Curve: DEPT, 	 Units: F, 	 Description: 1  DEPTH
# Curve: SP, 	 Units: MV, 	 Description: 2
# Curve: LL8, 	 Units: OHMM, 	 Description: 3
# Curve: ILM, 	 Units: OHMM, 	 Description: 4
# Curve: ILD, 	 Units: OHMM, 	 Description: 5
# Curve: MSFL, 	 Units: OHMM, 	 Description: 6
# Curve: LLS, 	 Units: OHMM, 	 Description: 7
# Curve: LLD, 	 Units: OHMM, 	 Description: 8
# Curve: CALI, 	 Units: IN, 	 Description: 9
# Curve: GR, 	 Units: GAPI, 	 Description: 10
# Curve: RHOB, 	 Units: G/C3, 	 Description: 11
# Curve: DRHO, 	 Units: G/C3, 	 Description: 12
# Curve: NPHI, 	 Units: %, 	 Description: 13
# Curve: DT, 	 Units: US/F, 	 Description: 14
# There are a total of: 14 curves present within this file

# %%
well = las.df()
well
# Out:
#          SP  LL8  ILM  ILD  MSFL  LLS  LLD  CALI       GR    RHOB    DRHO
# DEPT
# 50.0    NaN  NaN  NaN  NaN   NaN  NaN  NaN   NaN  28.7208     NaN     NaN  \
# 50.5    NaN  NaN  NaN  NaN   NaN  NaN  NaN   NaN  28.4001     NaN     NaN
# 51.0    NaN  NaN  NaN  NaN   NaN  NaN  NaN   NaN  28.1777     NaN     NaN
# 51.5    NaN  NaN  NaN  NaN   NaN  NaN  NaN   NaN  28.2867     NaN     NaN
# 52.0    NaN  NaN  NaN  NaN   NaN  NaN  NaN   NaN  28.7196     NaN     NaN
# ...      ..  ...  ...  ...   ...  ...  ...   ...      ...     ...     ...
# 20058.0 NaN  NaN  NaN  NaN   NaN  NaN  NaN   NaN  30.9243  2.7003 -0.0152
# 20058.5 NaN  NaN  NaN  NaN   NaN  NaN  NaN   NaN  31.2531  2.6920 -0.0158
# 20059.0 NaN  NaN  NaN  NaN   NaN  NaN  NaN   NaN  31.4536  2.6651 -0.0275
# 20059.5 NaN  NaN  NaN  NaN   NaN  NaN  NaN   NaN  31.3935  2.6734 -0.0197
# 20060.0 NaN  NaN  NaN  NaN   NaN  NaN  NaN   NaN  31.4575  2.6745 -0.0204
#
#            NPHI  DT
# DEPT
# 50.0        NaN NaN
# 50.5        NaN NaN
# 51.0        NaN NaN
# 51.5        NaN NaN
# 52.0        NaN NaN
# ...         ...  ..
# 20058.0  0.6115 NaN
# 20058.5  0.6260 NaN
# 20059.0  0.6405 NaN
# 20059.5  0.6550 NaN
# 20060.0  0.6646 NaN
#
# [40021 rows x 13 columns]

# %%
well.plot()
# Out:
# <Axes: xlabel='DEPT'>

# %%
for item in las.sections['Well']:
    print(f"{item.descr} ({item.mnemonic}): \t\t {item.value}")
# Out:
# START DEPTH (STRT): 		 50.0
# STOP DEPTH (STOP): 		 20060.0
# STEP VALUE (STEP): 		 0.5
# NULL VALUE (NULL): 		 -999.25
# COMPANY (COMP): 		 USGS/NPR HUSKY OIL OPERAT
# WELL (WELL): 		 INIGOK TEST WELL #1
# FIELD (FLD): 		 WILDCAT
# LOCATION (LOC): 		 34   8N   5W
# COUNTY (CNTY): 		 NORTH SLOPE
# STATE (STAT): 		 ALASKA
# COUNTRY (CTRY): 		 USA
# LOG DATE (DATE): 		 6/14/78
# UNIQUE WELL IDENTIFIER (API): 		 502792000300
# OPERATOR (OPER): 		 USGS/NPR HUSKY OIL OPERAT
# SERVICE COMPANY (SRVC): 		 Schlumberger
# UNIQUE WELL ID (UWI): 		 502792000300
# LATITUDE (LAT): 		 0.0
# LONGITUDE (LON): 		 0.0
# DIGITIZING COMPANY (DIGS): 		 Center Line Data

# %%
well.describe()
# Out:
#                      SP               LL8               ILM               ILD
# count  33498.0000000000  14210.0000000000  14151.0000000000  14210.0000000000  \
# mean     -55.5159755388    199.0211248276     96.5688567734    486.7634279873
# std       26.9270385233    413.7901084339    346.1674432000    759.4539002973
# min     -195.8090000000      1.4734000000      0.7497000000      1.5500000000
# 25%      -82.4755500000     10.1813000000      4.5754500000      8.4741250000
# 50%      -56.6262500000     28.0778000000      6.6968000000     27.9225500000
# 75%      -30.7362250000    142.5192250000     13.7144500000    808.5003750000
# max        3.6826000000   1983.5184000000   2297.0100000000   2335.7832000000
#
#                    MSFL                LLS               LLD
# count  19289.0000000000   24594.0000000000  2.4594000000e+04  \
# mean       7.0806771631      84.8999013255  2.0234963642e+02
# std       30.6730782322    4220.1000467310  1.2218636840e+04
# min        0.1936000000       0.2660000000  2.1420000000e-01
# 25%        1.0481000000       3.8989500000  6.3659500000e+00
# 50%        4.0651000000       5.3633000000  9.4160500000e+00
# 75%        9.9990000000       8.3602250000  1.2504575000e+01
# max     1970.7844000000  659198.8750000000  1.8950088750e+06
#
#                    CALI                GR              RHOB              DRHO
# count  32062.0000000000  37234.0000000000  32082.0000000000  32085.0000000000  \
# mean      15.3220467781     77.2392392142      2.3426350446      0.0585011501
# std        4.9395464262     31.6286408453      0.3091796165      0.0630953918
# min        6.5177000000      8.0356000000      1.0152000000     -0.2004000000
# 25%       10.4586250000     56.5074500000      2.1584000000      0.0083000000
# 50%       16.9193500000     85.2493000000      2.3884000000      0.0421000000
# 75%       20.2101750000     98.0181000000      2.5955750000      0.1060000000
# max       20.8263000000    233.0461000000      2.9997000000      0.2532000000
#
#                    NPHI                DT
# count  34969.0000000000  38791.0000000000
# mean      22.4132186537     80.1768572530
# std       17.0199001547     21.9168734383
# min       -0.9705000000     39.7136000000
# 25%        3.0639000000     61.6457500000
# 50%       25.1954000000     80.9745000000
# 75%       37.1821000000     93.8919000000
# max       60.0304000000    233.9562000000

# %%
depth = well.index.values
sp = well["SP"]

# %%
f = plt.figure(figsize=(2, 7))
plt.plot(sp, depth)
plt.gca().invert_yaxis()
plt.show()

# %%
fig, axes = plt.subplots(nrows=1, ncols=count)
colors = []
characters = []
# Out:
# <Axes: xlabel='DEPT'>

# %%
well.plot(y="SP")
# Out:
# <Axes: xlabel='DEPT'>

# %%
type(well)
# Out:
# pandas.core.frame.DataFrame

# %%
well.plot(y="CALI")
# Out:
# <Axes: xlabel='DEPT'>

# %%
type(2e+6)
# Out:
# float

# %%
well.plot(y="DT", figsize=(50, 25))
# Out:
# <Axes: xlabel='DEPT'>
